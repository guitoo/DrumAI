# %%
import tensorflow as tf
import ddsp
from ddsp.training import (data, decoders, encoders, models, preprocessing, 
                           train_util)

# %%
from matplotlib import pyplot as plt

# %%
import tensorflow as tf

# %%
import numpy as np
from scipy.fftpack import ifft, fftshift, fft
from scipy.signal import chebwin as schebwin

# %%
def beta(m, at):
    return np.cosh(1/(m-1) * np.arccosh(10**(at/20)))

def cheb (n, x):
    return np.where(np.less_equal(np.abs(x),1),
                    np.cos(n * np.arccos(x)),
                    np.where(np.less(x,0),
                             (1 - 2 * (n % 2)) * np.cosh(n * np.arccosh(-x)),
                             np.cosh(n * np.arccosh(x))))

def cheb(n, x):
    return np.where(np.less_equal(np.abs(x),1),
                    np.cos(n * np.arccos(x)),
                    ((x-np.sqrt(x**2-1))**n+(x+np.sqrt(x**2-1))**n)/2)


def chebwin(m, at):
    k = np.arange(0,m)
    b = beta(m,at)
    
    x = b*np.cos(np.pi*k/m)
        
    W = cheb(m-1, x)
    if m % 2:
        w = np.real(fft(W))
        w = fftshift(w)
    else:
        W = W * np.exp(1.j * np.pi*k/m)
        w = np.real(fft(W))
        w = np.roll(w,m//2-1)
    return w/max(w)

# %%
#plt.plot(chebwin(20, 60)[0])
plt.plot(chebwin(20, 60))
plt.plot(schebwin(20, 60))
# Out:
# /home/guillaume/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in arccos
#   del sys.path[0]
# /home/guillaume/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in sqrt

# %%
plt.plot(np.log(np.abs(fftshift(fft(chebwin(20, 60),1000)))))
# Out:
# /home/guillaume/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in arccos
#   del sys.path[0]
# /home/guillaume/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in sqrt
#
# /home/guillaume/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %%
order = 5
x = np.linspace(0, 1,order)*(order-1)
u = 5.6
relu = lambda x: np.maximum(x, 0)

# %%
h = np.sinc(x - (order - 1) / 2 - np.mod(u,1))
#h*window
h
# Out:
# array([ 0.11643488, -0.18920668,  0.50455115,  0.75682673, -0.21623621])

# %%
from ddsp.core import linear_lookup, tf_float32
from tensorflow.keras.layers import Layer, RNN
from ddsp import processors
from ddsp.processors import Processor, TensorDict

# %%
def delay_line(delay, audio):
    return tf.linalg.diag_part(linear_lookup(delay,audio))

# %%
class ProcessorCell(processors.Processor):
    
    def call(self, inputs: TensorDict, states) -> tf.Tensor:

        controls = self.get_controls(**inputs)
        signal = self.get_signal(**controls, states=states)
        return signal

# %%
#from tensorflow.keras.layers import Wrapper

class RNNProcessor(processors.Processor):
    
    def __init__(self, cell, name, trainable=False):
        self._layer = RNN(cell, return_sequences=True)
        super().__init__(name=name, trainable=trainable)
    
    def get_signal(self, **control):
        return self._layer(control)

# %%
class FeedbackDelayNetwork(RNNProcessor):
    
    def __init__(self, trainable=False, n_channels=3, max_delay=50, name="FDN"):
        super().__init__(FeedbackDelayNetworkCell(n_channels=n_channels, max_delay=max_delay, trainable=trainable),
                         name=name,
                         trainable=trainable)
    
    def get_controls(self, audio, delay=None, matrix=None):
        
        n_timesteps = audio.shape[1]
        if self.trainable:
            return {'audio': audio}
        # Repeat tensors along time if time dimension if not present.
        if len(delay.shape) == 2:
            delay = delay[:, tf.newaxis, :]
            delay = tf.repeat(delay, repeats=n_timesteps, axis=1)
        if len(matrix.shape) == 2:
            matrix = matrix[:, tf.newaxis, :]
            matrix = tf.repeat(matrix, repeats=n_timesteps, axis=1)
        
        return {'audio': audio, 'delay': delay, 'matrix': matrix}

# %%
#@gin.register
class FeedbackDelayNetworkCell(ProcessorCell):
    
    """feedback delay network
    
    audio shape [n_channels]
    delay shape [n_channels]
    matrix shape [n_channels, n_channels]
    states shape [n_channels, max_delay]
    """
    
    def __init__(self,
               trainable=False,
               n_channels=3,
               max_delay=50,
               name='FDN_cell'):
        super().__init__(name=name, trainable=trainable)
        self._n_channels = n_channels
        self._max_delay = max_delay
        self.state_size = n_channels * max_delay
    
    def build(self, unused_input_shape):
   
        if self.trainable:
            initializer = tf.random_normal_initializer(mean=0, stddev=1e-6)
            self._matrix = self.add_weight(
                name='mixing_matrix',
                shape=[self._n_channels, self._n_channels],
                dtype=tf.float32,
                initializer=initializer)
            self._delay = self.add_weight(
                name='delays',
                shape=[1,self._n_channels],
                dtype=tf.float32,
                initializer=initializer)
        self.built = True
        
    def get_controls(self, audio, delay=None, matrix=None):
        if self.trainable:
            delay = self._delay
            matrix = self._matrix
        else:
            if delay is None:
                raise ValueError('Must provide "delay" tensor if FDN trainable=False.')
            if matrix is None:
                raise ValueError('Must provide "matrix" tensor if FDN trainable=False.')

        matrix = tf.reshape(matrix, [n_channels, n_channels])
        return {'audio': audio, 'delay': delay, 'matrix': matrix}
    
    def get_signal(self, audio, delay, matrix, states):
        
        audio, delay, matrix = tf_float32(audio),tf_float32(delay),tf_float32(matrix)
        states = tf.reshape(states, [n_channels,max_delay])
        delayed = delay_line(delay,states)
        audio = delayed + audio
        mixed = tf.keras.backend.dot(audio, matrix)
        
        states = tf.slice(states, [0,1], [n_channels,max_delay-1])
        states = tf.concat([states, tf.transpose(mixed)], axis=1)
        audio = tf.math.reduce_sum(mixed, axis=1)
        
        return audio, [tf.reshape(states,[1,n_channels*max_delay])]

# def FeedbackDelayNetwork(n_channels=3, max_delay=50, name="FDN", trainable=False):
#     layer = RNN(FeedbackDelayNetworkCell(n_channels=n_channels, max_delay=max_delay, trainable=trainable), return_sequences=True)
#     params = ['audio', 'delay', 'matrix']
#     return RNNProcessor(layer, params, name)

# %%
n_channels = 3
max_delay = 10
signal_length = 100
audio = tf.random.uniform(shape=[1, signal_length, 1])
delay = tf.random.uniform(shape=[1, signal_length, n_channels])
matrix = tf.random.uniform(shape=[1, signal_length, n_channels*n_channels])/n_channels

fdn = FeedbackDelayNetwork(n_channels=n_channels, max_delay=max_delay)
fdn(audio,delay,matrix)
# Out:
# <tf.Tensor: shape=(1, 100), dtype=float32, numpy=
# array([[0.356724  , 0.02414934, 0.8014234 , 0.12432793, 1.3494767 ,
#         1.4226842 , 0.6522787 , 1.5742807 , 1.1236706 , 0.5997714 ,
#         0.8280581 , 0.3124102 , 1.004169  , 0.86262083, 1.2978613 ,
#         1.0404065 , 0.7516655 , 1.6441469 , 1.1777825 , 0.48300192,
#         0.6020684 , 0.5744448 , 0.8908958 , 0.80333674, 0.71184903,
#         0.74854195, 0.6185049 , 0.4871292 , 0.4512267 , 1.1506243 ,
#         0.72367734, 1.5567467 , 1.3712088 , 0.9211664 , 1.3638799 ,
#         1.0045023 , 1.3725159 , 0.8927511 , 0.9905286 , 2.766137  ,
#         2.250405  , 2.3786132 , 1.3247328 , 2.3516595 , 1.2002379 ,
#         1.5400946 , 1.6865648 , 1.9849582 , 1.0172532 , 1.1464132 ,
#         1.4313647 , 1.877947  , 1.3683028 , 1.892037  , 1.2536367 ,
#         1.8670244 , 1.0601162 , 2.279695  , 0.66163224, 0.8970575 ,
#         1.0904157 , 1.8606942 , 0.9843483 , 1.7107816 , 1.9131463 ,
#         0.8666494 , 1.8350562 , 0.9225439 , 0.95616746, 1.6928445 ,
#         0.91571337, 1.7668382 , 2.1201568 , 0.8222324 , 1.4094929 ,
#         1.0553049 , 1.1861863 , 1.3441961 , 0.8147931 , 0.9687352 ,
#         1.7237282 , 2.236405  , 0.8301832 , 0.58442664, 0.7342415 ,
#         0.7114217 , 1.5189047 , 1.4244395 , 1.0677495 , 1.0104892 ,
#         1.7869616 , 0.697489  , 0.56567764, 0.4596704 , 1.5626845 ,
#         1.3863723 , 1.3974283 , 2.0746377 , 0.55907255, 1.2729448 ]],
#       dtype=float32)>

# %%
audio = tf.random.uniform(shape=[1, signal_length, 1])
delay = tf.random.uniform(shape=[1, n_channels])
matrix = tf.random.uniform(shape=[1, n_channels*n_channels])/n_channels

fdn = FeedbackDelayNetwork(n_channels=n_channels, max_delay=max_delay)
fdn(audio,delay,matrix)
# Out:
# <tf.Tensor: shape=(1, 100), dtype=float32, numpy=
# array([[0.986532  , 0.7392373 , 0.78170234, 1.4687605 , 1.2063103 ,
#         1.5499249 , 1.0302528 , 0.6571047 , 0.4069244 , 0.75689685,
#         0.8394661 , 0.44104457, 0.87338376, 1.4167743 , 1.5427363 ,
#         0.9960357 , 1.0934246 , 0.89038634, 0.50265884, 0.71572244,
#         0.34036368, 1.2862399 , 1.0879223 , 0.8887234 , 0.98971015,
#         0.43793994, 0.7049358 , 1.2082496 , 1.5610405 , 1.0527258 ,
#         1.1136218 , 0.9349607 , 1.0889006 , 1.5939814 , 1.7063012 ,
#         1.5409895 , 0.713096  , 1.4782376 , 1.2209704 , 0.99190456,
#         1.1541713 , 0.67327803, 0.42008498, 0.32959116, 1.202081  ,
#         1.5301771 , 1.6982925 , 1.4544154 , 1.639279  , 1.7758898 ,
#         0.82748795, 0.54520947, 1.3986726 , 0.8698735 , 1.0942414 ,
#         1.2765117 , 0.98243177, 1.3239186 , 0.7231046 , 0.6657821 ,
#         0.60849345, 0.8881222 , 0.7179664 , 1.1066486 , 1.5109468 ,
#         1.7142818 , 1.0740242 , 1.4109931 , 0.88603604, 0.8437876 ,
#         0.6334743 , 0.8732476 , 1.2812753 , 1.6126144 , 1.5607176 ,
#         1.7886674 , 1.3604194 , 0.96967125, 1.5814153 , 0.8519677 ,
#         0.6425824 , 0.6449512 , 0.76986086, 0.31123427, 0.23640889,
#         0.5987817 , 0.17898336, 0.83382475, 0.34888458, 0.23595312,
#         0.78368986, 1.1009154 , 0.7693041 , 1.332871  , 1.1197044 ,
#         0.97805446, 0.82361484, 0.91547316, 0.5491611 , 1.4413943 ]],
#       dtype=float32)>

# %%
audio = tf.random.uniform(shape=[1, signal_length, 1])

fdn = FeedbackDelayNetwork(n_channels=n_channels, max_delay=max_delay, trainable=True)
fdn(audio)
# Out:
# <tf.Tensor: shape=(1, 100), dtype=float32, numpy=
# array([[-1.0191981e-06, -1.4805327e-06, -1.4250851e-06, -4.3560865e-07,
#         -9.5385781e-07, -5.0781239e-07, -1.0634022e-06, -6.6866917e-08,
#         -6.2590254e-07, -1.1483511e-06, -1.0672015e-06, -9.2795077e-08,
#         -1.1644893e-06, -5.3203001e-07, -2.5560126e-07, -1.4739364e-06,
#         -1.1506770e-06, -8.3521985e-07, -7.6128475e-07, -1.3792861e-06,
#         -1.2235383e-06, -1.0361557e-06, -9.8640896e-07, -3.5074393e-08,
#         -9.6794440e-07, -4.6442187e-07, -7.2688522e-07, -3.4507008e-07,
#         -1.2262448e-06, -1.1707403e-06, -4.6757572e-07, -4.5102541e-07,
#         -1.0024449e-06, -1.2460501e-06, -1.3931689e-06, -7.3701875e-07,
#         -7.5565521e-07, -1.1495508e-06, -8.5860179e-08, -7.0590850e-08,
#         -5.5895259e-07, -7.4065474e-07, -5.6878997e-07, -4.9992417e-07,
#         -4.2324352e-08, -5.4761557e-07, -6.7859537e-07, -2.9883188e-07,
#         -3.0591119e-07, -7.3904397e-07, -1.2893779e-06, -1.3742829e-06,
#         -8.5452413e-08, -5.1231962e-07, -1.5310255e-07, -1.1218277e-06,
#         -1.1656351e-06, -1.2616183e-06, -2.6386377e-07, -2.5976729e-07,
#         -2.0677105e-07, -6.1870736e-07, -7.7036776e-07, -9.9604472e-07,
#         -3.1443395e-07, -9.2596991e-08, -1.5578975e-06, -1.1231407e-06,
#         -1.2548825e-06, -2.1018356e-07, -6.8643516e-07, -9.4839993e-07,
#         -1.5584875e-06, -1.4710268e-06, -5.1845768e-07, -4.1229683e-08,
#         -1.2087960e-06, -6.0540299e-07, -1.1443559e-06, -1.1692224e-06,
#         -9.3963536e-07, -1.5348675e-06, -1.4887800e-06, -6.5947120e-07,
#         -9.2319021e-07, -9.4151744e-07, -3.2237440e-07, -9.9664430e-07,
#         -1.4147732e-06, -1.3483084e-06, -1.0196540e-06, -3.3853206e-07,
#         -1.0447496e-06, -8.8419813e-07, -1.5074606e-06, -6.5352697e-07,
#         -6.0547745e-07, -4.8533985e-07, -1.5180210e-06, -1.0997553e-06]],
#       dtype=float32)>

# %%
audio = tf.random.uniform(shape=[1,signal_length,1])
delay = tf.random.uniform(shape=[1,signal_length,n_channels])
matrix = tf.random.uniform(shape=[1,signal_length,n_channels*n_channels])
test = tf.concat([audio, delay, matrix], axis=2)
print(test.shape)
audio, delay, matrix = tf.split(test, [1, n_channels, n_channels*n_channels], axis=2)

# %%
states = tf.random.uniform(shape=[n_channels,max_delay])
audio_out = tf.slice(states, [0,1], [n_channels,max_delay-1])

# %%
def generator(n_channels = 3, max_delay = 10, signal_length = 100):
    
    while(true):
        audio = tf.random.uniform(shape=[1, signal_length, 1])
        delay = tf.random.uniform(shape=[1, signal_length, n_channels])
        matrix = tf.random.uniform(shape=[1, signal_length, n_channels*n_channels])/n_channels
        inputs = tf.concat([audio, delay, matrix], axis=2)
        yield inputs

# %%
#class FDNDecoder(Decoder):

# %%
from ddsp.training import (data, decoders, encoders, models, preprocessing, 
                           train_util)

# %%
strategy = train_util.get_strategy()
spectral_loss = ddsp.losses.SpectralLoss(loss_type='L1',
                                         mag_weight=1.0,
                                         logmag_weight=1.0)
decoder = 
                            
fdn = RNN(FeedbackDelayNetworkCell(n_channels=n_channels, max_delay=max_delay), return_sequences=True)

dag = [fdn, ['inputs']]
processor_group = ddsp.processors.ProcessorGroup(dag=dag,
                                                 name='processor_group')

with strategy.scope():
  # Put it together in a model.
  model = models.Autoencoder(preprocessor=None,
                             encoder=None,
                             decoder=decoder,
                             processor_group=processor_group,
                             losses=[spectral_loss])
  trainer = train_util.Trainer(model, strategy, learning_rate=1e-3)
